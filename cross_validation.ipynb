# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objs as go

from datetime import timedelta

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score

# %%
data_8=pd.read_csv("dj_ft_8_dummy.csv")
data_9=pd.read_csv("dj_ft_9_dummy.csv")
data_10=pd.read_csv("dj_ft_10_dummy.csv")
data_11=pd.read_csv("dj_ft_11_dummy.csv")
data_12=pd.read_csv("dj_ft_12_dummy.csv")
data_13=pd.read_csv("dj_ft_13_dummy.csv")
data_14=pd.read_csv("dj_ft_14_dummy.csv")
data_15=pd.read_csv("dj_ft_15_dummy.csv")
data_16=pd.read_csv("dj_ft_16_dummy.csv")
data_17=pd.read_csv("dj_ft_17_dummy.csv")
data_18=pd.read_csv("dj_ft_18_dummy.csv")
data_19=pd.read_csv("dj_ft_19_dummy.csv")

# %%
data_8['energy'].plot()
# Out:
# <AxesSubplot:>

# %%
data_9['energy'].plot()
# Out:
# <AxesSubplot:>

# %%
data_10['energy'].plot()
# Out:
# <AxesSubplot:>

# %%
data_11['energy'].plot()
# Out:
# <AxesSubplot:>

# %%
data_12['energy'].plot()
# Out:
# <AxesSubplot:>

# %%
data_13['energy'].plot()
# Out:
# <AxesSubplot:>

# %%
# 시간별 X,Y 생성

Y_8=data_8['energy']
X_8=data_8.drop(['energy'],axis=1)

Y_9=data_9['energy']
X_9=data_9.drop(['energy'],axis=1)

Y_10=data_10['energy']
X_10=data_10.drop(['energy'],axis=1)


Y_11=data_11['energy']
X_11=data_11.drop(['energy'],axis=1)


Y_12=data_12['energy']
X_12=data_12.drop(['energy'],axis=1)


Y_13=data_13['energy']
X_13=data_13.drop(['energy'],axis=1)


Y_14=data_14['energy']
X_14=data_14.drop(['energy'],axis=1)


Y_15=data_15['energy']
X_15=data_15.drop(['energy'],axis=1)


Y_16=data_16['energy']
X_16=data_16.drop(['energy'],axis=1)


Y_17=data_17['energy']
X_17=data_17.drop(['energy'],axis=1)


Y_18=data_18['energy']
X_18=data_18.drop(['energy'],axis=1)


Y_19=data_19['energy']
X_19=data_19.drop(['energy'],axis=1)

# %% [markdown]
# ## 시간별 최적 모형찾기

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objs as go

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score

from sklearn.neighbors import KNeighborsRegressor # k-최근접 이웃 회귀 #분류대신 값을 예측
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from lightgbm import LGBMRegressor



#개별 모델 성능 (MAE) 확인

knn_model = KNeighborsRegressor()
svr_model = SVR()
lr_model = LinearRegression()
rf_model = RandomForestRegressor()
lgb_model = LGBMRegressor()

# %%
y=Y_8
X_train_m=X_8

cross_score_knn = cross_val_score(knn_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lr = cross_val_score(lr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_svr = cross_val_score(svr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_rf = cross_val_score(rf_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lgb = cross_val_score(lgb_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)


r_score_knn = -cross_score_knn/3040*5
r_score_lr = -cross_score_lr/3040*5
r_score_svr = -cross_score_svr/3040*5
r_score_rf = -cross_score_rf/3040*5
r_score_lgb = -cross_score_lgb/3040*5

print("KNN score :",r_score_knn, " / KNN mean score", r_score_knn.mean())
print("LR score :",r_score_lr, " / LR mean score", r_score_lr.mean()) #best
print("SVR score :",r_score_svr, " / SVR mean score", r_score_svr.mean())
print("RF score :",r_score_rf, " / RF score", r_score_rf.mean())
print("LGB score :",r_score_lgb, " /LGB score", r_score_lgb.mean())
# Out:
# KNN score : [1.72714331 0.88090124 1.66875119 1.36829027 1.36330383]  / KNN mean score 1.4016779668914894
# LR score : [0.71911894 0.33902372 0.76909198 0.46929324 0.88206367]  / LR mean score 0.6357183090741634
# SVR score : [2.1051299  0.75322131 1.15554801 1.68208826 1.1064694 ]  / SVR mean score 1.3604913765285551
# RF score : [1.05647136 0.31290068 0.99464817 0.52738302 1.09313541]  / RF score 0.796907728491718
# LGB score : [0.86667684 0.34494608 0.90999039 0.49715317 0.99035869]  /LGB score 0.721825033122423

# %%
y=Y_9
X_train_m=X_9

cross_score_knn = cross_val_score(knn_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lr = cross_val_score(lr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_svr = cross_val_score(svr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_rf = cross_val_score(rf_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lgb = cross_val_score(lgb_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)


r_score_knn = -cross_score_knn/3040*5
r_score_lr = -cross_score_lr/3040*5
r_score_svr = -cross_score_svr/3040*5
r_score_rf = -cross_score_rf/3040*5
r_score_lgb = -cross_score_lgb/3040*5

print("KNN score :",r_score_knn, " / KNN mean score", r_score_knn.mean())
print("LR score :",r_score_lr, " / LR mean score", r_score_lr.mean()) #best
print("SVR score :",r_score_svr, " / SVR mean score", r_score_svr.mean())
print("RF score :",r_score_rf, " / RF score", r_score_rf.mean())
print("LGB score :",r_score_lgb, " /LGB score", r_score_lgb.mean())
# Out:
# KNN score : [7.10169977 3.71889297 4.82064772 4.43931159 5.11541444]  / KNN mean score 5.039193299668486
# LR score : [3.90752574 2.38790383 3.40166538 2.35637318 3.8373768 ]  / LR mean score 3.1781689828286934
# SVR score : [9.80670941 5.39544068 5.15668656 7.88045846 7.3864506 ]  / SVR mean score 7.125149140643157
# RF score : [4.5527896  2.75525426 4.12466582 2.58157043 4.31837353]  / RF score 3.666530728090984
# LGB score : [4.25360975 2.93154103 4.25398362 2.56796862 4.2344086 ]  /LGB score 3.6483023236533896

# %%
y=Y_10
X_train_m=X_10

cross_score_knn = cross_val_score(knn_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lr = cross_val_score(lr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_svr = cross_val_score(svr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_rf = cross_val_score(rf_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lgb = cross_val_score(lgb_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)


r_score_knn = -cross_score_knn/3040*5
r_score_lr = -cross_score_lr/3040*5
r_score_svr = -cross_score_svr/3040*5
r_score_rf = -cross_score_rf/3040*5
r_score_lgb = -cross_score_lgb/3040*5

print("KNN score :",r_score_knn, " / KNN mean score", r_score_knn.mean())
print("LR score :",r_score_lr, " / LR mean score", r_score_lr.mean()) #best
print("SVR score :",r_score_svr, " / SVR mean score", r_score_svr.mean())
print("RF score :",r_score_rf, " / RF score", r_score_rf.mean())
print("LGB score :",r_score_lgb, " /LGB score", r_score_lgb.mean())
# Out:
# KNN score : [30.95763126 18.66496569 24.4329599  17.4596837  24.42681807]  / KNN mean score 23.18841172418302
# LR score : [12.82879378  9.5112431  10.85101049  6.79959394  9.73194299]  / LR mean score 9.94451685958552
# SVR score : [27.38369931 19.06879929 17.2452239  21.12937723 24.00700496]  / SVR mean score 21.766820939192943
# RF score : [13.93493285 10.06195047 13.37684704  7.80750806 11.45651249]  / RF score 11.327550181145032
# LGB score : [14.11920863 12.04523309 12.37071681  8.67562295 11.6625943 ]  /LGB score 11.774675155878976

# %%
y=Y_11
X_train_m=X_11

cross_score_knn = cross_val_score(knn_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lr = cross_val_score(lr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_svr = cross_val_score(svr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_rf = cross_val_score(rf_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lgb = cross_val_score(lgb_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)


r_score_knn = -cross_score_knn/3040*5
r_score_lr = -cross_score_lr/3040*5
r_score_svr = -cross_score_svr/3040*5
r_score_rf = -cross_score_rf/3040*5
r_score_lgb = -cross_score_lgb/3040*5

print("KNN score :",r_score_knn, " / KNN mean score", r_score_knn.mean())
print("LR score :",r_score_lr, " / LR mean score", r_score_lr.mean()) #best
print("SVR score :",r_score_svr, " / SVR mean score", r_score_svr.mean())
print("RF score :",r_score_rf, " / RF score", r_score_rf.mean())
print("LGB score :",r_score_lgb, " /LGB score", r_score_lgb.mean())
# Out:
# KNN score : [53.82784085 33.64564499 52.37284563 37.97300428 48.71433455]  / KNN mean score 45.30673406063005
# LR score : [22.92522248 19.97701104 18.17192887 13.28044079 19.31465742]  / LR mean score 18.73385211799908
# SVR score : [48.25009949 35.47680178 36.25675921 41.24142593 49.79617519]  / SVR mean score 42.204252321477455
# RF score : [25.86511432 22.28919692 19.37489795 15.8646692  20.72577776]  / RF score 20.823931229530913
# LGB score : [27.3906406  23.44329142 20.38637486 16.88563938 20.25136455]  /LGB score 21.671462160817757

# %%
y=Y_12
X_train_m=X_12

cross_score_knn = cross_val_score(knn_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lr = cross_val_score(lr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_svr = cross_val_score(svr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_rf = cross_val_score(rf_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lgb = cross_val_score(lgb_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)


r_score_knn = -cross_score_knn/3040*5
r_score_lr = -cross_score_lr/3040*5
r_score_svr = -cross_score_svr/3040*5
r_score_rf = -cross_score_rf/3040*5
r_score_lgb = -cross_score_lgb/3040*5

print("KNN score :",r_score_knn, " / KNN mean score", r_score_knn.mean())
print("LR score :",r_score_lr, " / LR mean score", r_score_lr.mean()) #best
print("SVR score :",r_score_svr, " / SVR mean score", r_score_svr.mean())
print("RF score :",r_score_rf, " / RF score", r_score_rf.mean())
print("LGB score :",r_score_lgb, " /LGB score", r_score_lgb.mean())
# Out:
# KNN score : [50.20595395 37.3384812  34.55033084 34.88971607 39.37796871]  / KNN mean score 39.272490152714326
# LR score : [33.94029171 26.13887843 28.3298838  20.34531556 25.09613273]  / LR mean score 26.770100445360118
# SVR score : [64.57412395 51.8498608  54.04995533 57.43913617 69.42728167]  / SVR mean score 59.46807158334691
# RF score : [36.71212534 35.87610337 28.396466   24.63375819 26.67714455]  / RF score 30.459119488236844
# LGB score : [35.65834104 30.61526673 27.69377242 24.98508072 26.74360664]  /LGB score 29.13921351170594

# %%
y=Y_13
X_train_m=X_13

cross_score_knn = cross_val_score(knn_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lr = cross_val_score(lr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_svr = cross_val_score(svr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_rf = cross_val_score(rf_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lgb = cross_val_score(lgb_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)


r_score_knn = -cross_score_knn/3040*5
r_score_lr = -cross_score_lr/3040*5
r_score_svr = -cross_score_svr/3040*5
r_score_rf = -cross_score_rf/3040*5
r_score_lgb = -cross_score_lgb/3040*5

print("KNN score :",r_score_knn, " / KNN mean score", r_score_knn.mean())
print("LR score :",r_score_lr, " / LR mean score", r_score_lr.mean()) #best
print("SVR score :",r_score_svr, " / SVR mean score", r_score_svr.mean())
print("RF score :",r_score_rf, " / RF score", r_score_rf.mean())
print("LGB score :",r_score_lgb, " /LGB score", r_score_lgb.mean())
# Out:
# KNN score : [73.94467043 60.32522932 66.70083858 57.47504061 62.53336471]  / KNN mean score 64.19582872851987
# LR score : [39.58835471 27.65507623 31.66556136 24.49170841 26.7562335 ]  / LR mean score 30.0313868421709
# SVR score : [67.74322418 66.13305294 67.22531102 65.09482437 71.4504297 ]  / SVR mean score 67.52936844275084
# RF score : [49.21474745 32.17436634 34.38044643 29.74582436 27.54972827]  / RF score 34.613022568025926
# LGB score : [48.76521777 33.26609757 34.35659549 29.80821084 32.34259482]  /LGB score 35.70774329912423

# %%
y=Y_14
X_train_m=X_14

cross_score_knn = cross_val_score(knn_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lr = cross_val_score(lr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_svr = cross_val_score(svr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_rf = cross_val_score(rf_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lgb = cross_val_score(lgb_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)


r_score_knn = -cross_score_knn/3040*5
r_score_lr = -cross_score_lr/3040*5
r_score_svr = -cross_score_svr/3040*5
r_score_rf = -cross_score_rf/3040*5
r_score_lgb = -cross_score_lgb/3040*5

print("KNN score :",r_score_knn, " / KNN mean score", r_score_knn.mean())
print("LR score :",r_score_lr, " / LR mean score", r_score_lr.mean()) #best
print("SVR score :",r_score_svr, " / SVR mean score", r_score_svr.mean())
print("RF score :",r_score_rf, " / RF score", r_score_rf.mean())
print("LGB score :",r_score_lgb, " /LGB score", r_score_lgb.mean())
# Out:
# KNN score : [84.82124245 60.08498332 79.74710212 55.91494177 74.16715461]  / KNN mean score 70.94708484953412
# LR score : [33.45491633 20.10844306 31.78893514 21.39104927 28.85244896]  / LR mean score 27.119158550679323
# SVR score : [66.66808798 59.63936494 74.47329323 65.13326839 83.92703478]  / SVR mean score 69.96820986604385
# RF score : [42.23162443 28.55729242 30.62832013 26.39230782 33.82821951]  / RF score 32.327552861150494
# LGB score : [43.07193285 25.38581724 31.80168162 26.94426548 31.47178301]  /LGB score 31.735096039993635

# %%
y=Y_15
X_train_m=X_15

cross_score_knn = cross_val_score(knn_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lr = cross_val_score(lr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_svr = cross_val_score(svr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_rf = cross_val_score(rf_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lgb = cross_val_score(lgb_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)


r_score_knn = -cross_score_knn/3040*5
r_score_lr = -cross_score_lr/3040*5
r_score_svr = -cross_score_svr/3040*5
r_score_rf = -cross_score_rf/3040*5
r_score_lgb = -cross_score_lgb/3040*5

print("KNN score :",r_score_knn, " / KNN mean score", r_score_knn.mean())
print("LR score :",r_score_lr, " / LR mean score", r_score_lr.mean()) #best
print("SVR score :",r_score_svr, " / SVR mean score", r_score_svr.mean())
print("RF score :",r_score_rf, " / RF score", r_score_rf.mean())
print("LGB score :",r_score_lgb, " /LGB score", r_score_lgb.mean())
# Out:
# KNN score : [73.35517848 45.11035507 50.83599566 41.95230672 51.03988416]  / KNN mean score 52.45874401913875
# LR score : [33.09762238 27.67240827 31.69733368 20.50972019 28.61834095]  / LR mean score 28.3190850913599
# SVR score : [71.28347035 55.21291473 63.89126761 55.49327194 79.5983615 ]  / SVR mean score 65.09585722663076
# RF score : [35.91235534 39.79283385 33.25161128 26.14811768 32.95093248]  / RF score 33.61117012480442
# LGB score : [36.20423091 33.96761945 33.85223845 28.20915466 30.64340175]  /LGB score 32.575329045986265

# %%
y=Y_16
X_train_m=X_16

cross_score_knn = cross_val_score(knn_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lr = cross_val_score(lr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_svr = cross_val_score(svr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_rf = cross_val_score(rf_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lgb = cross_val_score(lgb_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)


r_score_knn = -cross_score_knn/3040*5
r_score_lr = -cross_score_lr/3040*5
r_score_svr = -cross_score_svr/3040*5
r_score_rf = -cross_score_rf/3040*5
r_score_lgb = -cross_score_lgb/3040*5

print("KNN score :",r_score_knn, " / KNN mean score", r_score_knn.mean())
print("LR score :",r_score_lr, " / LR mean score", r_score_lr.mean()) #best
print("SVR score :",r_score_svr, " / SVR mean score", r_score_svr.mean())
print("RF score :",r_score_rf, " / RF score", r_score_rf.mean())
print("LGB score :",r_score_lgb, " /LGB score", r_score_lgb.mean())
# Out:
# KNN score : [79.71921777 53.01780408 59.17203286 40.75804624 56.04850392]  / KNN mean score 57.743120974723
# LR score : [39.30004824 21.77262386 26.00997995 15.92442136 19.85443459]  / LR mean score 24.572301601710333
# SVR score : [81.27128486 42.42701028 45.45307417 40.12877325 59.61310307]  / SVR mean score 53.77864912454155
# RF score : [44.45109495 23.45499833 25.38888953 15.24702219 26.22368092]  / RF score 26.95313718268444
# LGB score : [39.52950524 24.66226701 27.32060498 18.98105954 24.84158293]  /LGB score 27.06700394278589

# %%
y=Y_17
X_train_m=X_17

cross_score_knn = cross_val_score(knn_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lr = cross_val_score(lr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_svr = cross_val_score(svr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_rf = cross_val_score(rf_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lgb = cross_val_score(lgb_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)


r_score_knn = -cross_score_knn/3040*5
r_score_lr = -cross_score_lr/3040*5
r_score_svr = -cross_score_svr/3040*5
r_score_rf = -cross_score_rf/3040*5
r_score_lgb = -cross_score_lgb/3040*5

print("KNN score :",r_score_knn, " / KNN mean score", r_score_knn.mean())
print("LR score :",r_score_lr, " / LR mean score", r_score_lr.mean()) #best
print("SVR score :",r_score_svr, " / SVR mean score", r_score_svr.mean())
print("RF score :",r_score_rf, " / RF score", r_score_rf.mean())
print("LGB score :",r_score_lgb, " /LGB score", r_score_lgb.mean())
# Out:
# KNN score : [54.81151694 30.75647931 37.95295831 23.74714132 35.89276253]  / KNN mean score 36.63217168159058
# LR score : [24.50923248 12.13107483 15.08315899 11.90946542 11.84876919]  / LR mean score 15.09634018138416
# SVR score : [73.69587493 26.10086547 32.49934276 26.44621241 24.87200178]  / SVR mean score 36.722859470722376
# RF score : [28.31682685 11.91909242 13.54872732 12.08953822 11.94747983]  / RF score 15.564332928383726
# LGB score : [25.65875844 12.12062769 13.97832439 12.14046286 11.26950685]  /LGB score 15.033536045582874

# %%
y=Y_18
X_train_m=X_18

cross_score_knn = cross_val_score(knn_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lr = cross_val_score(lr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_svr = cross_val_score(svr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_rf = cross_val_score(rf_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lgb = cross_val_score(lgb_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)


r_score_knn = -cross_score_knn/3040*5
r_score_lr = -cross_score_lr/3040*5
r_score_svr = -cross_score_svr/3040*5
r_score_rf = -cross_score_rf/3040*5
r_score_lgb = -cross_score_lgb/3040*5

print("KNN score :",r_score_knn, " / KNN mean score", r_score_knn.mean())
print("LR score :",r_score_lr, " / LR mean score", r_score_lr.mean()) #best
print("SVR score :",r_score_svr, " / SVR mean score", r_score_svr.mean())
print("RF score :",r_score_rf, " / RF score", r_score_rf.mean())
print("LGB score :",r_score_lgb, " /LGB score", r_score_lgb.mean())
# Out:
# KNN score : [17.94340796  6.22371106 12.60007284  5.03938495 13.76390486]  / KNN mean score 11.114096334930734
# LR score : [9.02197336 3.85306616 7.193627   4.13760139 5.24967994]  / LR mean score 5.891189570057678
# SVR score : [34.74559956  7.22817905 19.50761587  9.1039214   6.8343456 ]  / SVR mean score 15.483932296637835
# RF score : [10.08788704  2.53791236  6.64667932  4.53953245  5.24300583]  / RF score 5.811003399641933
# LGB score : [8.6315076  4.02174028 6.69412608 4.86774603 4.65262767]  /LGB score 5.773549533147864

# %%
y=Y_19
X_train_m=X_19

cross_score_knn = cross_val_score(knn_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lr = cross_val_score(lr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_svr = cross_val_score(svr_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_rf = cross_val_score(rf_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)
cross_score_lgb = cross_val_score(lgb_model, X_train_m, y, scoring='neg_mean_squared_error', cv=5)


r_score_knn = -cross_score_knn/3040*5
r_score_lr = -cross_score_lr/3040*5
r_score_svr = -cross_score_svr/3040*5
r_score_rf = -cross_score_rf/3040*5
r_score_lgb = -cross_score_lgb/3040*5

print("KNN score :",r_score_knn, " / KNN mean score", r_score_knn.mean())
print("LR score :",r_score_lr, " / LR mean score", r_score_lr.mean()) #best
print("SVR score :",r_score_svr, " / SVR mean score", r_score_svr.mean())
print("RF score :",r_score_rf, " / RF score", r_score_rf.mean())
print("LGB score :",r_score_lgb, " /LGB score", r_score_lgb.mean())
# Out:
# KNN score : [3.248934   2.41873598 3.69990293 1.91004368 2.69607474]  / KNN mean score 2.79473826609707
# LR score : [1.46422076 0.79580556 1.73062748 1.09419237 1.62883173]  / LR mean score 1.342735580572063
# SVR score : [3.95536893 2.44177124 4.94682004 1.07672372 1.89528246]  / SVR mean score 2.863193278719695
# RF score : [1.71974828 1.19532522 1.68236015 0.87558484 1.59321923]  / RF score 1.4132475416500065
# LGB score : [1.64700579 1.10399709 1.663425   0.89485359 1.487704  ]  /LGB score 1.3593970942908458

# %% [markdown]
# ## dj_ft
# ## 17,19는 lr 보다는 random Forest가 좋다
# ## 18 은 lgb
# ## 나머지는 lr
